# %%
import os
import pandas as pd
import numpy as np
import re
import warnings
warnings.filterwarnings("ignore")
import csv 
import datetime


pd.set_option('display.max_rows', 10)

import warnings
warnings.filterwarnings("ignore")
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.display import * 
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', -1)
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# - Baseline file used: CJARS_data_docs_2021_p163_p169.pdf
# - This file contains the broad classifications of all the charges.

# %% [markdown]
# - Methodology
#     1. Check for occurences of crimes using broad terms mentioned in CJARS document.
#         - Example: use str.contains to check occurences of keyword 'murder'.
#         - If all the occurences on checking categorize correctly into 'violent charges' in this case, mark all those records with 'violent crimes' categorization.
#         - One way to do this is: wa_df['Type_Of_Crime'] = np.where(wa_df['Law_Description'].str.contains('murder'), 'violent crimes', wa_df.Type_Of_Crime) #hit and run unattended vehicle
#     2. After checking for keywords from the CJARS document, split the charges into keywords and observe the occurences.
#         - Example: 'child abuse' can be searched independently as 'child' and 'abuse'.
#         - Now go through these occurences and find patterns and conditions to mark them into their respective crime classifications.
#             - For example, on searching strings with the word 'child', crimes such as sexual assualt on child shows up. We can mark all charges containing keywords 'child' and 'sex' as 'violent'.
#         - Repeat this step for all different categorizations.
#     3. Check for charges by shortening the charge names and looking out for spelling mistakes due to poor record keeping.
#         - Example: Assault also occurs as 'aslt', 'assualt', 'asslt', etc.

# %% [markdown]
# - 6 main Crime Classifications:
#     1. Violent crimes
#     2. Public Order crimes
#     3. Drug crimes
#     4. Traffic crimes
#     5. Dui crimes
#     6. Property crimes

# %%
# %%time
ca_df = pd.read_csv('CA Charges by Frequency - Sheet1.csv', error_bad_lines = False)
ca_df.head()
# Out:
# CPU times: user 9.94 ms, sys: 5.13 ms, total: 15.1 ms
# Wall time: 16.9 ms
#                                      Charge   Count Percent
# 0  NO ARREST RECEIVED                        352530  6.39%
# 1  23152(A) VC-DUI ALCOHOL/DRUGS             186627  3.38%
# 2  23152(B) VC-DUI ALCOHOL/0.08 PERCENT      169502  3.07%
# 3  SEE COMMENT FOR CHARGE                    139560  2.53%
# 4  11377(A) HS-POSSESS CONTROLLED SUBSTANCE  129035  2.34%

# %%
ca_df.shape[0]
# Out:
# 4864

# %%
ca_df.Charge.nunique()
# Out:
# 4864

# %%
ca_df['Charge'] = ca_df['Charge'].str.lower()

# %%
ca_df.head()
# Out:
#                                      Charge   Count Percent
# 0  no arrest received                        352530  6.39%
# 1  23152(a) vc-dui alcohol/drugs             186627  3.38%
# 2  23152(b) vc-dui alcohol/0.08 percent      169502  3.07%
# 3  see comment for charge                    139560  2.53%
# 4  11377(a) hs-possess controlled substance  129035  2.34%

# %%
ca_df["Crime_Classification"] = ''

# %%
ca_df.head()
# Out:
#                                      Charge   Count Percent  \
# 0  no arrest received                        352530  6.39%
# 1  23152(a) vc-dui alcohol/drugs             186627  3.38%
# 2  23152(b) vc-dui alcohol/0.08 percent      169502  3.07%
# 3  see comment for charge                    139560  2.53%
# 4  11377(a) hs-possess controlled substance  129035  2.34%
#
#   Crime_Classification
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# #### Checking for violent crimes

# %%
print(list(ca_df[ca_df['Charge'].str.contains('pc-murder', na=False)].Charge.unique()))
print()
print(list(ca_df[ca_df['Charge'].str.contains('manslaughter', na=False)].Charge.unique()))
print()
print(list(ca_df[ca_df['Charge'].str.contains('kidnapping', na=False)].Charge.unique()))
print()
print(list(ca_df[ca_df['Charge'].str.contains('robbery', na=False)].Charge.unique()))
print()
print(list(ca_df[ca_df['Charge'].str.contains('carjacking', na=False)].Charge.unique()))
print()
print(list(ca_df[ca_df['Charge'].str.contains('assault', na=False)].Charge.unique()))
print()
print(list(ca_df[ca_df['Charge'].str.contains('battery', na=False)].Charge.unique()))
print()
# Out:
# ['187(a) pc-murder', '187 pc-murder', '187(a) pc-murder:first degree', '187(a) pc-murder:second degree', '187 pc-murder:second degree', '187 pc-murder:first degree', '187(a) pc-murder:first deg:shoot from vehicle', '187(a) pc-murder:sec deg on peace officer', '189 pc-murder', '189 pc-murder:first degree', '189 pc-murder:second degree', '190 pc-murder', '187/190.2 pc-murder first/spec circumstance']
#
# ['192(a) pc-voluntary manslaughter', '192(b) pc-involuntary manslaughter', '192.1 pc-voluntary manslaughter', '192 pc-manslaughter', '192.3 pc-manslaughter/vehicle', '192.2 pc-involuntary manslaughter', '192(c) pc-manslaughter/vehicle', '193(a) pc-voluntary manslaughter', '193(c) pc-vehicle manslaughter', '193 pc-manslaughter', '193(b) pc-involuntary manslaughter', 'homicide/manslaughter', '182 pc-conspiracy/homicide/manslaughter']
#
# ['207(a) pc-kidnapping', '207 pc-kidnapping', '209(b) pc-kidnapping to commit robbery', '209(a) pc-kidnapping for ransom', '209 pc-kidnapping for ransom', '207(b) pc-kidnapping:specific circumstances', '208(b) pc-kidnapping child under 14 years old', '207(c) pc-kidnapping:specific circumstances', '208 pc-kidnapping', 'kidnapping', '664 pc-attempt crime/kidnapping']
#
# ['211 pc-robbery', '211 pc-robbery:second degree', '212.5(c) pc-robbery:second degree', '212.5(b) pc-robbery:second degree', '211 pc-robbery:first degree', '211 pc-armed robbery', '212.5 pc-robbery', '211 pc-strongarm robbery', '209(b)(1) pc-kidnap:commit robbery/rape/etc', '209(b) pc-kidnapping to commit robbery', '212.5(b) pc-robbery:first degree:atm/etc', '211/12022.5 pc-robbery with firearm', '211a pc-robbery:first degree', '220 pc-assault to commit rape/robbery/etc', '18 2113(a) us-bank/etc robbery', '213(a)(2) pc-robbery:second degree', '211a pc-robbery of common carrier', '212 pc-fear as element in robbery', '211a pc-robbery', '220 pc-assault to commit robbery', '209 pc-kidnap for ransom/etc or robbery', '213 pc-robbery', '211/12022(a) pc-robbery while armed', '211/12022(b) pc-robbery w/use deadly weapon', '209(b)(1) pc-kidnap to commit robbery', '213(b) pc-attempted robbery:second degree', '213(b) pc-attempted robbery', '211a pc-robbery:second degree', '211/12022 pc-robbery while armed', 'robbery', '211 pc-robbery 1st deg home invasion in concrt', '211/12022.7 pc-robbery with gbi', '213.1 pc-robbery:first degree', '602 wi-juvenile/robbery', '214 pc-train robbery']
#
# ['215(a) pc-carjacking', '215 pc-carjacking', '209.5(a) pc-kidnap during carjacking']
#
# ['245(a)(2) pc-assault with firearm on person', '240 pc-assault', '245(a) pc-assault with deadly weapon', '245(a)(1) pc-assault w/deadly weapon:not f/arm', '240/242 pc-assault & battery', '245 pc-assault with deadly weapon', '240 pc-assault on person', '4501 pc-assault by prisoner', '241(b) pc-assault peace ofcr/emerg persnl/etc', '220 pc-assault to commit rape', '12280(b) pc-possess any assault weapon', '245(b) pc-assault person w/semiauto firearm', '217 pc-assault w/intent to murder', '241(a) pc-assault on person', '220 pc-assault to commit mayhem/rape etc', '30605(a) pc-ill poss any assault weapon', '240 pc-assault peace ofcr/emerg persnl/etc', '241(c) pc-assault on po/firefighter/etc', '244 pc-assault with caustic chemical/etc', '467 pc-possess weapon to commit assault', '241 pc-assault peace officer/fireman', '12280(a)(1) pc-mfg/etc any assault weapon', '245(c) pc-assault with firearm on p.o./fireman', '241.1 pc-assault on custodial officer', '4500 pc-assault by life prisoner', '245(a) pc-assault w/intent to comm bodily harm', '12024 pc-poss deadly wpn:commit assault', '220(a)(1) pc-assault:w/intent to rape', '240 pc-assault peace officer/fireman', '241 pc-assault peace officer', '220 pc-assault to commit rape/robbery/etc', '220/261 pc-assault to commit rape', '244.5(b) pc-assault with stun gun/taser', '241 pc-assault on person', '220 pc-assault to commit mayhem', '241.2(a) pc-assault:person on school/park prop', '30600(a) pc-mfg/sell/trans/etc assault wpn', '241.6 pc-assault on school employee', '245 pc-assault w/intent to commit bodily harm', '17500 pc-poss deadly weapon:commit assault', '30605(a) pc-ill possess any assault weapon', '149 pc-assault by public officer', '245(a)(3) pc-assault w/machinegun on person', '12280 pc-mfg/trans/poss/etc any assault wpn', '220 pc-assault to commit robbery', '220 pc-assault to commit lewd/lasc act:child', '240 pc-assault,aslt peace ofc/simple assault', '217.1(a) pc-assault public official', '220 pc-assault to commit oral copulation', '240 pc-simple assault', '243.6 pc-assault or battery on process server', 'assault', '241.2(a) pc-assault person on school property', '220 pc-assault to commit sodomy', '220(a)(2) pc-assault:-18 yrs w/intent to rape', '221 pc-assault to commit other felony', '243.5 pc-assault or battery on school property', '286.5 pc-sexual assault on animal', '1768.8(b) wi-assault on non-prisoner:gbi', '241.4 pc-assault school district peace officer', '244.5 pc-assault with stun gun/taser', '220 pc-assault to penetrate w/foreign object', '220 pc-assault to commit grand larceny', '241.3 pc-assault on transportation personnel', 'sexual assault', '220 pc-assault:commit lewd/lasc act on child', '18 113(a)(5) us-simple assault:mar juris', '18 113(a)(4) us-assault by striking/beating', '217.1 pc-att to kill/assault exec/judicial ofc', '245.5(c) pc-assault sch emp w/stun gun/taser', '245.5(b) pc-assault w/firearm on sch employee', '243.5(a) pc-assault/battery on school property', '241.7 pc-assault on jurors', '18 113(a)(6) us-assault resulting in sbi', '664 pc-attempt crime/assault']
#
# ['242 pc-battery', '242 pc-battery on person', '243(a) pc-battery on person', '243(b) pc-battery peace ofcr/emerg persnl/etc', '243(d) pc-battery with serious bodily injury', '243(e) pc-battery:spouse/etc', '240/242 pc-assault & battery', '242/243(a) pc-battery', '243.4(a) pc-sexual battery', '243 pc-battery', '242 pc-battery with serious bodily injury', '4501.5 pc-battery by prisoner', '243 pc-battery on peace officer/fireman', '243(c)(2) pc-battery against police officer', '243.4 pc-sexual battery', '243(c)(1) pc-battery emergency person/etc', '243.1 pc-battery on custodial officer', '242/243(d) pc-battery with serious bodily inj', '243.6 pc-battery on school employee', '242 pc-battery p.o./emerg persnl/etc w/o inj', '242 pc-battery against peace officer', '242 pc-battery on peace officer/fireman', '242/243 pc-battery', '242 pc-battery p.o./emerg persnl/etc w/injury', '243.2 pc-battery on person on school property', '243 pc-battery peace ofcr/emergency persnl/etc', '242 pc-battery emergency person/etc', '242 pc-battery or battery peace officer', '243.6 pc-battery on school employee w/injury', '242/243 pc-battery p.o./emerg persnl w/injury', '4131.5 pc-battery on noninmate by jail inmate', '243 pc-battery with serious bodily injury', '243 pc-battery on peace officer w/injury', '243.6 pc-assault or battery on process server', '243 pc-battery on citizen w/great bodily inj', '243.15 pc-battery of noninmate while in custdy', '243.5 pc-assault or battery on school property', '243.8(a) pc-battery against sports official', '242/243.1 pc-battery custodial officer', '243.2 pc-battery/doj peace officer', '243.4 pc-battery/school peace officer', '243.8 pc-battery against sports official', '243.4 pc-battery/federal peace officer', '243(c) pc-battery po/emergency prsnl/etc w/inj', '243.5(a) pc-assault/battery on school property', '537f pc-sell rebuilt battery w/out label']

# %%
# Classifying violent crimes

# %%
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('pc-murder'),
                                                      'Violent', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('mansl'),
                                                      'Violent', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('kidnap'),
                                                      'Violent', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('robbery'),
                                                      'Violent', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('carjacking'),
                                                      'Violent', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('assault'),
                                                      'Violent', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('battery'),
                                                      'Violent', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('rape'),
                                                      'Violent', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('sex'),
                                                      'Violent', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('abuse'),
                                                      'Violent', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('threat'),
                                                      'Violent', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('inj'),
                                                      'Violent', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('homicide'),
                                                      'Violent', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('violent'),
                                                      'Violent', ca_df.Crime_Classification)

ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('trafficking'),
                                                      'Violent', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('extortion'),
                                                      'Violent', ca_df.Crime_Classification)

ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('armed'),
                                                      'Violent', ca_df.Crime_Classification)

# %%
ca_df.loc[ca_df['Crime_Classification'] == 'Violent']
# Out:
#                                               Charge  Count Percent  \
# 12    242 pc-battery                                  66240  1.20%
# 13    273.5(a) pc-inflict corporal inj spouse/cohab   64477  1.17%
# 24    211 pc-robbery                                  43833  0.79%
# 28    273.5 pc-inflict corporal inj on spouse/cohab   38858  0.70%
# 43    422 pc-threaten crime with intent to terrorize  27907  0.51%
# ...                                              ...    ...    ...
# 4833  290.006 pc-court order reg/finding:sex grat     1      0.00%
# 4835  290.006 pc-290 viol:sexual grat/compulsion      1      0.00%
# 4837  290(g)(5) pc-sex viol predator fail verify reg  1      0.00%
# 4838  290(f)(3) pc-sex reg fail rpt name chng to lea  1      0.00%
# 4861  301 hn-injure/etc 10 ton or more vessel         1      0.00%
#
#      Crime_Classification
# 12    Violent
# 13    Violent
# 24    Violent
# 28    Violent
# 43    Violent
# ...       ...
# 4833  Violent
# 4835  Violent
# 4837  Violent
# 4838  Violent
# 4861  Violent
#
# [586 rows x 4 columns]

# %%
#ca_df.to_csv('file_name.csv', sep='\t', index=False)

# %%
# Classifying property crimes

# %%
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('arson'),
                                                      'property', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('property'),
                                                      'property', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('burglary'),
                                                      'property', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('forgery'),
                                                      'property', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('theft'),
                                                      'property', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('vandalism'),
                                                      'property', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('fraud'),
                                                      'property', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('financial'),
                                                      'property', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('trespass'),
                                                      'property', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('destruct'),
                                                      'property', ca_df.Crime_Classification)

# %%
ca_df.loc[ca_df['Crime_Classification'] == 'property']
# Out:
#                                               Charge   Count Percent  \
# 5     459 pc-burglary                                 124904  2.27%
# 15    496(a) pc-receive/etc known stolen property     58093   1.05%
# 19    10851(a) vc-take veh w/o own consent/veh theft  53832   0.98%
# 25    488 pc-petty theft                              43589   0.79%
# 31    484(a) pc-theft                                 37780   0.69%
# ...               ...                                   ...     ...
# 4676  498(b)(1) pc-theft divert utility srvs $950+    1       0.00%
# 4715  286(f)(3) pc-sodomy:vict unaware:perpet fraud   1       0.00%
# 4764  261(a)(4)(c) pc-rape:victim of perp fraud       1       0.00%
# 4785  31411 cc-fraud of franchise                     1       0.00%
# 4807  36 2.31(a)(2) us-fr:tamper with property        1       0.00%
#
#      Crime_Classification
# 5     property
# 15    property
# 19    property
# 25    property
# 31    property
# ...        ...
# 4676  property
# 4715  property
# 4764  property
# 4785  property
# 4807  property
#
# [496 rows x 4 columns]

# %%
# Classifying drug crimes

# %%
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('heroin'),
                                                      'drug', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('cocaine'),
                                                      'drug', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('prescription'),
                                                      'drug', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('controlled'),
                                                      'drug', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('marijuana'),
                                                      'drug', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('paraphernalia'),
                                                      'drug', ca_df.Crime_Classification)

# %%
ca_df.loc[ca_df['Crime_Classification'] == 'drug']
# Out:
#                                              Charge   Count Percent  \
# 4     11377(a) hs-possess controlled substance       129035  2.34%
# 39    11359 hs-possess marijuana for sale            28867   0.52%
# 61    11364(a) hs-possess unlaw paraphernalia        18713   0.34%
# 65    11351.5 hs-poss/purchase cocaine base f/sale   16556   0.30%
# 68    11377 hs-possess controlled substance          16414   0.30%
# ...                                     ...            ...     ...
# 4526  11162 hs-prescriptions must conform to law     1       0.00%
# 4530  11161 hs-write unauthorized prescription       1       0.00%
# 4566  4237 bp-forged prescription                    1       0.00%
# 4604  11166.05 hs-possess prescription blanks        1       0.00%
# 4850  308(a)(2)(b) pc-mnr buy smoking paraphernalia  1       0.00%
#
#      Crime_Classification
# 4     drug
# 39    drug
# 61    drug
# 65    drug
# 68    drug
# ...    ...
# 4526  drug
# 4530  drug
# 4566  drug
# 4604  drug
# 4850  drug
#
# [86 rows x 4 columns]

# %%
# Classifying DUI crimes

# %%
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('driving'),
                                                      'DUI', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('dui'),
                                                      'DUI', ca_df.Crime_Classification)

# %%
ca_df.loc[ca_df['Crime_Classification'] == 'DUI']
# Out:
#                                               Charge   Count Percent  \
# 1     23152(a) vc-dui alcohol/drugs                   186627  3.38%
# 2     23152(b) vc-dui alcohol/0.08 percent            169502  3.07%
# 22    14601.2(a) vc-drive:lic susp/etc:dui:spec viol  48960   0.89%
# 32    23152(a)/23152(b) vc-dui:alcohol/drugs          36643   0.66%
# 42    23152(a) vc-dui alcohol                         28109   0.51%
# ...                       ...                           ...     ...
# 4207  502 vc-misdemeanor drunk/narcotic driving       2       0.00%
# 4320  23106(b) vc-dui any drug not on highway         1       0.00%
# 4549  38317 vc-reckless driving off-hwy veh:w/injury  1       0.00%
# 4612  506(a) vc-dui narcotic drugs                    1       0.00%
# 4633  506(b) vc-dui nonnarcotic drugs                 1       0.00%
#
#      Crime_Classification
# 1     DUI
# 2     DUI
# 22    DUI
# 32    DUI
# 42    DUI
# ...   ...
# 4207  DUI
# 4320  DUI
# 4549  DUI
# 4612  DUI
# 4633  DUI
#
# [104 rows x 4 columns]

# %%
# Public order crimes

# %%
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('riot'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('custody'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('prosecution'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('weapons'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('habitual offender'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('parole'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('probation'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('contempt'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('court order'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('morals'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('decency'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('immigration'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('obstruction'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('resist'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('privacy'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('invasion'),
                                                      'public order crime', ca_df.Crime_Classification)

ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('commercialize'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('deliquency'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('disorder'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('liqour'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('law violation'),
                                                      'public order crime', ca_df.Crime_Classification)

ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('tax'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('bribe'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('conflict of interest'),
                                                      'public order crime', ca_df.Crime_Classification)
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('public order offense'),
                                                      'public order crime', ca_df.Crime_Classification)

# %%
ca_df.loc[ca_df['Crime_Classification'] == 'public order crime']
# Out:
#                                              Charge  Count Percent  \
# 11    violation of parole                            68178  1.24%
# 18    3056 pc-violation of parole:felony             55014  1.00%
# 26    647(f) pc-disorderly conduct:intox drug/alcoh  40545  0.74%
# 30    1203.2 pc-probation viol:rearrest/revoke       37897  0.69%
# 37    647(b) pc-disorderly conduct:prostitution      29476  0.53%
# ...                                         ...        ...    ...
# 4643  601(a) wi-mnr violate juvenile court order     1      0.00%
# 4682  279 pc-conceal child/violate custody order     1      0.00%
# 4766  26 7201 us-evade/etc federal taxes             1      0.00%
# 4798  639 pc-bribe employee to obtain loan           1      0.00%
# 4833  290.006 pc-court order reg/finding:sex grat    1      0.00%
#
#      Crime_Classification
# 11    public order crime
# 18    public order crime
# 26    public order crime
# 30    public order crime
# 37    public order crime
# ...                  ...
# 4643  public order crime
# 4682  public order crime
# 4766  public order crime
# 4798  public order crime
# 4833  public order crime
#
# [169 rows x 4 columns]

# %%
# Criminal Traffic

# %%
print(list(ca_df[ca_df['Charge'].str.contains('traffic', na=False)].Charge.unique()))
# Out:
# ['traffic violation', 'traffic offense', '14601.3(a) vc-habitual traffic offender', '21657 vc-disobey designated traffic direction', 'traffic inf vc-traffic violations', '21804(a) vc-fail yield to traffic:hwy entrance', '21655.5 vc-disobey traffic lane signs', '21461.5 vc-pedestrian fail obey traffic signs', '236.1(a) pc-human trafficking/force labor', '236.1(c) pc-human trafficking/-18yrs', '236.1(b) pc-human traffic:deprv prsnl liberty', '42005(e) vc-fail to attend:traffic school', '36 4.12 us-fed reg:traffic cntl device viol', '22517 vc-vehicle door open to traffic', '21367(b) vc-disobey construction traffic cntl', '21462 vc-all traffic/etc obey signals', '21100.3 vc-fail to obey traffic regulator', '42005(g) vc-fail to attend traffic school', '21464(c) vc-intrfer w/traffic device:death/inj', '21465 vc-unauth dsply traffic device/sign', '18 2318(a) us-trafficking counterfeit labels']

# %%
ca_df['Crime_Classification'] = np.where(ca_df.Charge.str.contains('traffic'),
                                                      'Criminal Traffic', ca_df.Crime_Classification)

# %%
ca_df.loc[ca_df['Crime_Classification'] == 'Criminal Traffic']
# Out:
#                                               Charge  Count Percent  \
# 141   traffic violation                               6725   0.12%
# 469   traffic offense                                 974    0.02%
# 555   14601.3(a) vc-habitual traffic offender         701    0.01%
# 950   21657 vc-disobey designated traffic direction   254    0.00%
# 961   traffic inf vc-traffic violations               246    0.00%
# ...                                 ...               ...      ...
# 3150  21100.3 vc-fail to obey traffic regulator       7      0.00%
# 3618  42005(g) vc-fail to attend traffic school       4      0.00%
# 3621  21464(c) vc-intrfer w/traffic device:death/inj  4      0.00%
# 4116  21465 vc-unauth dsply traffic device/sign       2      0.00%
# 4388  18 2318(a) us-trafficking counterfeit labels    1      0.00%
#
#      Crime_Classification
# 141   Criminal Traffic
# 469   Criminal Traffic
# 555   Criminal Traffic
# 950   Criminal Traffic
# 961   Criminal Traffic
# ...                ...
# 3150  Criminal Traffic
# 3618  Criminal Traffic
# 3621  Criminal Traffic
# 4116  Criminal Traffic
# 4388  Criminal Traffic
#
# [21 rows x 4 columns]

# %%
# Not known/missing

# %%
print(list(ca_df[ca_df['Charge'].str.contains('felony', na=False)].Charge.unique()))
print()


print(list(ca_df[ca_df['Charge'].str.contains('misdemeanor', na=False)].Charge.unique()))
print()
# Out:
# ['3056 pc-violation of parole:felony', '1320(b) pc-failure to appear on felony charge', '667.5(b) pc-pr prison:new felony:enhance term', '978.5 pc-bench warrant:fta:felony charge', '1320.5 pc-failure to appear on felony charge', '979 pc-bench warrant:fail appear:felony chg', '367e pc-felony drunk driving', '667(a)(1) pc-prior felony conviction', '290(g)(2) pc-fail reg/etc felony sex off/pr', '667(a) pc-prior felony conviction', '12025(b)(1) pc-ccw in vehicle w/pr felony conv', '667 pc-prior felony conviction', '647f pc-felony prostitution', '25400(c)(1) pc-ccw in vehicle w/pr felony conv', '12023(a) pc-carry loaded firearm:commit felony', '25800(a) pc-carry loaded firearm:commit felony', '12021.1(c) pc-pos/etc f/arm:specific felony', '182.5 pc-conspiracy commit felony:gang member', '4532(b)(1) pc-escape:felony charge pending', '23175.5 vc-dui within 10 yrs of pr felony dui', '12023 pc-commit felony w/dangerous weapon', '221 pc-assault to commit other felony', '222 pc-give drugs to aid in felony', '23550.5 vc-dui within 10 yr of pr felony dui', '653j(a) pc-solicit minor to commit spec felony', 'violate probation/felony']
#
# ['1320(a) pc-fail appear:misdemeanor charge', '978.5 pc-bench warrant:fta:misdemeanor charge', '23102(a) vc-misdemeanor drunk driving', '23102 vc-misdemeanor/dui liquor/drug', '3056 pc-violation of parole:misdemeanor', '659 pc-counsel/aid in misdemeanor', '23102(b) vc-misdemeanor drunk driving w/prior', '367d pc-misdemeanor drunk driving', '23102.5 vc-dui toluene/poison,misdemeanor', '23102.5(a) vc-dui toluene/poison,misdemeanor', '502 vc-misdemeanor drunk/narcotic driving']

# %%
# Save to csv

# %%
ca_df.to_csv('CA_Classify.csv', sep='\t', index=False)
